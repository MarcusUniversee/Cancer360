# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * **GENDER :** M [Male] , F [Female]
# * **AGE :** Age of patients
# * **SMOKING :** 2 [Yes] , 1 [No]
# * **YELLOW_FINGERS :** 2 [Yes] , 1 [No]
# * **ANXIETY :** 2 [Yes] , 1 [No]
# * **PEER_PRESSURE :** 2 [Yes] , 1 [No]
# * **CHRONIC DISEASE :** 2 [Yes] , 1 [No]
# * **FATIGUE :** 2 [Yes] , 1 [No]
# * **ALLERGY :** 2 [Yes] , 1 [No]
# * **WHEEZING :** 2 [Yes] , 1 [No]
# * **ALCOHOL CONSUMING :** 2 [Yes] , 1 [No]
# * **COUGHING :** 2 [Yes] , 1 [No]
# * **SHORTNESS OF BREATH :** 2 [Yes] , 1 [No]
# * **SWALLOWING DIFFICULTY :** 2 [Yes] , 1 [No]
# * **CHEST PAIN :** 2 [Yes] , 1 [No]
# * **LUNG_CANCER :** YES [Positive] , NO [Negative]

# %%
data = pd.read_csv("survey lung cancer.csv")

# %%
data_temp = data.copy()
data_temp["GENDER"] = data_temp["GENDER"].replace({"M" : "Male" , "F" : "Female"})

for column in data_temp.columns:
    data_temp[column] = data_temp[column].replace({2: "Yes" , 1 : "No"})

data_temp.head().style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_c337c_row0_col0, #T_c337c_row0_col1, #T_c337c_row0_col2, #T_c337c_row0_col3, #T_c337c_row0_col4, #T_c337c_row0_col5, #T_c337c_row0_col6, #T_c337c_row0_col7, #T_c337c_row0_col8, #T_c337c_row0_col9, #T_c337c_row0_col10, #T_c337c_row0_col11, #T_c337c_row0_col12, #T_c337c_row0_col13, #T_c337c_row0_col14, #T_c337c_row0_col15, #T_c337c_row1_col0, #T_c337c_row1_col1, #T_c337c_row1_col2, #T_c337c_row1_col3, #T_c337c_row1_col4, #T_c337c_row1_col5, #T_c337c_row1_col6, #T_c337c_row1_col7, #T_c337c_row1_col8, #T_c337c_row1_col9, #T_c337c_row1_col10, #T_c337c_row1_col11, #T_c337c_row1_col12, #T_c337c_row1_col13, #T_c337c_row1_col14, #T_c337c_row1_col15, #T_c337c_row2_col0, #T_c337c_row2_col1, #T_c337c_row2_col2, #T_c337c_row2_col3, #T_c337c_row2_col4, #T_c337c_row2_col5, #T_c337c_row2_col6, #T_c337c_row2_col7, #T_c337c_row2_col8, #T_c337c_row2_col9, #T_c337c_row2_col10, #T_c337c_row2_col11, #T_c337c_row2_col12, #T_c337c_row2_col13, #T_c337c_row2_col14, #T_c337c_row2_col15, #T_c337c_row3_col0, #T_c337c_row3_col1, #T_c337c_row3_col2, #T_c337c_row3_col3, #T_c337c_row3_col4, #T_c337c_row3_col5, #T_c337c_row3_col6, #T_c337c_row3_col7, #T_c337c_row3_col8, #T_c337c_row3_col9, #T_c337c_row3_col10, #T_c337c_row3_col11, #T_c337c_row3_col12, #T_c337c_row3_col13, #T_c337c_row3_col14, #T_c337c_row3_col15, #T_c337c_row4_col0, #T_c337c_row4_col1, #T_c337c_row4_col2, #T_c337c_row4_col3, #T_c337c_row4_col4, #T_c337c_row4_col5, #T_c337c_row4_col6, #T_c337c_row4_col7, #T_c337c_row4_col8, #T_c337c_row4_col9, #T_c337c_row4_col10, #T_c337c_row4_col11, #T_c337c_row4_col12, #T_c337c_row4_col13, #T_c337c_row4_col14, #T_c337c_row4_col15 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_c337c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c337c_level0_col0" class="col_heading level0 col0" >GENDER</th>
#       <th id="T_c337c_level0_col1" class="col_heading level0 col1" >AGE</th>
#       <th id="T_c337c_level0_col2" class="col_heading level0 col2" >SMOKING</th>
#       <th id="T_c337c_level0_col3" class="col_heading level0 col3" >YELLOW_FINGERS</th>
#       <th id="T_c337c_level0_col4" class="col_heading level0 col4" >ANXIETY</th>
#       <th id="T_c337c_level0_col5" class="col_heading level0 col5" >PEER_PRESSURE</th>
#       <th id="T_c337c_level0_col6" class="col_heading level0 col6" >CHRONIC DISEASE</th>
#       <th id="T_c337c_level0_col7" class="col_heading level0 col7" >FATIGUE </th>
#       <th id="T_c337c_level0_col8" class="col_heading level0 col8" >ALLERGY </th>
#       <th id="T
, #T_1991d_row3_col10, #T_1991d_row3_col11, #T_1991d_row3_col12, #T_1991d_row3_col13, #T_1991d_row3_col14, #T_1991d_row3_col15, #T_1991d_row4_col0, #T_1991d_row4_col1, #T_1991d_row4_col2, #T_1991d_row4_col3, #T_1991d_row4_col4, #T_1991d_row4_col5, #T_1991d_row4_col6, #T_1991d_row4_col7, #T_1991d_row4_col8, #T_1991d_row4_col9, #T_1991d_row4_col10, #T_1991d_row4_col11, #T_1991d_row4_col12, #T_1991d_row4_col13, #T_1991d_row4_col14, #T_1991d_row4_col15 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_1991d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1991d_level0_col0" class="col_heading level0 col0" >AGE</th>
#       <th id="T_1991d_level0_col1" class="col_heading level0 col1" >MALE</th>
#       <th id="T_1991d_level0_col2" class="col_heading level0 col2" >FEMALE</th>
#       <th id="T_1991d_level0_col3" class="col_heading level0 col3" >ALCOHOL CONSUMING</th>
#       <th id="T_1991d_level0_col4" class="col_heading level0 col4" >CHEST PAIN</th>
#       <th id="T_1991d_level0_col5" class="col_heading level0 col5" >SHORTNESS OF BREATH</th>
#       <th id="T_1991d_level0_col6" class="col_heading level0 col6" >COUGHING</th>
#       <th id="T_1991d_level0_col7" class="col_heading level0 col7" >PEER PRESSURE</th>
#       <th id="T_1991d_level0_col8" class="col_heading level0 col8" >CHRONIC DISEASE</th>
#       <th id="T_1991d_level0_col9" class="col_heading level0 col9" >SWALLOWING DIFFICULTY</th>
#       <th id="T_1991d_level0_col10" class="col_heading level0 col10" >YELLOW FINGERS</th>
#       <th id="T_1991d_level0_col11" class="col_heading level0 col11" >ANXIETY</th>
#       <th id="T_1991d_level0_col12" class="col_heading level0 col12" >FATIGUE</th>
#       <th id="T_1991d_level0_col13" class="col_heading level0 col13" >ALLERGY</th>
#       <th id="T_1991d_level0_col14" class="col_heading level0 col14" >WHEEZING</th>
#       <th id="T_1991d_level0_col15" class="col_heading level0 col15" >LUNG CANCER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1991d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1991d_row0_col0" class="data row0 col0" >69</td>
#       <td id="T_1991d_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_1991d_row0_col2" class="data row0 col2" >False</td>
#       <td id="T_1991d_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_1991d_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_1991d_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_1991d_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_1991d_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_1991d_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_1991d_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_1991d_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_1991d_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_1991d_row0_col12" class="data row0 col12" >2</td>
#       <td id="T_1991d_row0_col13" class="data row0 col13" >1</td>
#       <td id="T_1991d_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_1991d_row0_col15" class="data row0 col15" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1991d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1991d_row1_col0" class="data row1 col0" >74</td>
#       <td id="T_1991d_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_1991d_row1_col2" class="data row1 col2" >False</td>
#       <td id="T_1991d_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_1991d_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_1991d_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_1991d_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_1991d_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_1991d_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_1991d_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_1991d_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_1991d_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_1991d_row1_col12" class="data row1 col12" >2</td>
#       <td id="T_1991d_row1_col13" class="data row1 col13" >2</td>
#       <td id="T_1991d_row1_col14" class="data row1 col14" >1</td>
#       <td id="T_1991d_row1_col15" class="data row1 col15" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1991d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1991d_row2_col0" class="data row2 col0" >59</td>
#       <td id="T_1991d_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_1991d_row2_col2" class="data row2 col2" >True</td>
#       <td id="T_1991d_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_1991d_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_1991d_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_1991d_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_1991d_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_1991d_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_1991d_row2_col9" class="data row2 col9" >1</td>
#       <td id="T_1991d_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_1991d_row2_col11" class="data row2 col11" >1</td>
#       <td id="T_1991d_row2_col12" class="data row2 col12" >2</td>
#       <td id="T_1991d_row2_col13" class="data row2 col13" >1</td>
#       <td id="T_1991d_row2_col14" class="data row2 col14" >2</td>
#       <td id="T_1991d_row2_col15" class="data row2 col15" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1991d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1991d_row3_col0" class="data row3 col0" >63</td>
#       <td id="T_1991d_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_1991d_row3_col2" class="data row3 col2" >False</td>
#       <td id="T_1991d_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_1991d_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_1991d_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_1991d_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_1991d_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_1991d_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_1991d_row3_col9" class="data row3 col9" >2</td>
#       <td id="T_1991d_row3_col10" class="data row3 col10" >2</td>
#       <td id="T_1991d_row3_col11" class="data row3 col11" >2</td>
#       <td id="T_1991d_row3_col12" class="data row3 col12" >1</td>
#       <td id="T_1991d_row3_col13" class="data row3 col13" >1</td>
#       <td id="T_1991d_row3_col14" class="data row3 col14" >1</td>
#       <td id="T_1991d_row3_col15" class="data row3 col15" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1991d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1991d_row4_col0" class="data row4 col0" >63</td>
#       <td id="T_1991d_row4_col1" class="data row4 col1" >False</td>
#       <td

# %%
x = data.drop("LUNG CANCER", axis = 1)
y = data["LUNG CANCER"]

# from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# scaler = StandardScaler()
# x = scaler.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

print(f"Shape of training data : {x_train.shape}, {y_train.shape}")
print(f"Shape of testing data : {x_test.shape}, {y_test.shape}")
# Out:
# Shape of training data : (247, 15), (247,)
# Shape of testing data : (62, 15), (62,)

# %%
x_train
# Out:
#      AGE   MALE  FEMALE  ALCOHOL CONSUMING  CHEST PAIN  SHORTNESS OF BREATH  \
# 126   51   True   False                  2           2                    2
# 109   53   True   False                  2           2                    2
# 247   67   True   False                  2           1                    2
# 234   77   True   False                  2           1                    1
# 202   74   True   False                  2           2                    1
# ..   ...    ...     ...                ...         ...                  ...
# 188   65   True   False                  1           1                    1
# 71    66  False    True                  1           1                    2
# 106   61  False    True                  1           1                    2
# 270   70  False    True                  1           1                    2
# 102   64   True   False                  2           2                    2
#
#      COUGHING  PEER PRESSURE  CHRONIC DISEASE  SWALLOWING DIFFICULTY  \
# 126         2              1                1                      1
# 109         1              1                2                      1
# 247         2              1                1                      1
# 234         2              2                1                      1
# 202         1              1                2                      2
# ..        ...            ...              ...                    ...
# 188         1              2                2                      1
# 71          2              2                1                      2
# 106         1              2                2                      2
# 270         1              1                1                      1
# 102         2              1                1                      1
#
#      YELLOW FINGERS  ANXIETY  FATIGUE  ALLERGY  WHEEZING
# 126               1        1        2        1         2
# 109               1        1        2        2         1
# 247               2        1        2        1         2
# 234               2        1        2        2         2
# 202               1        1        2        2         2
# ..              ...      ...      ...      ...       ...
# 188               2        2        1        1         1
# 71                2        2        2        1         2
# 106               2        2        2        1         1
# 270               1        1        2        1         1
# 102               1        1        2        2         2
#
# [247 rows x 15 columns]

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(use_label_encoder = False)
xgb.fit(x_train, y_train)
xgb_pred = xgb.predict(np.array(x_test))
xgb_conf = confusion_matrix(y_test, xgb_pred)
xgb_report = classification_report(y_test, xgb_pred)
xgb_acc = round(accuracy_score(y_test, xgb_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{xgb_conf}")
print(f"\nClassification Report : \n\n{xgb_report}")
print(f"\nThe Accuracy of Extreme Gradient Boosting Classifier is {xgb_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 1  1]
#  [ 0 60]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       0.98      1.00      0.99        60
#
#     accuracy                           0.98        62
#    macro avg       0.99      0.75      0.83        62
# weighted avg       0.98      0.98      0.98        62
#
#
# The Accuracy of Extreme Gradient Boosting Classifier is 98.39 %

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 777.8 kB/s eta 0:00:00 0:00:01
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.1
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
from xgboost import plot_tree
plot_tree(xgb)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/graphviz/backend/execute.py:79, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      78         kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 79     proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      80 else:
#
# File /opt/homebrew/lib/python3.11/site-packages/graphviz/backend/execute.py:99, in _run_input_lines(cmd, input_lines, kwargs)
#      98 def _run_input_lines(cmd, input_lines, *, kwargs):
# ---> 99     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#     101     stdin_write = popen.stdin.write
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:1950, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1949         err_msg = os.strerror(errno_num)
# -> 1950     raise child_exception_type(errno_num, err_msg, err_filename)
#    1951 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: PosixPath('dot')
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# Cell In[81], line 2
#       1 from xgboost import plot_tree
# ----> 2 plot_tree(xgb)
#       3 plt.show()
#
# File /opt/homebrew/lib/python3.11/site-packages/xgboost/plotting.py:289, in plot_tree(booster, fmap, num_trees, rankdir, ax, **kwargs)
#     286 g = to_graphviz(booster, fmap=fmap, num_trees=num_trees, rankdir=rankdir, **kwargs)
#     288 s = BytesIO()
# --> 289 s.write(g.pipe(format="png"))
#     290 s.seek(0)
#     291 img = image.imread(s)
#
# File /opt/homebrew/lib/python3.11/site-packages/graphviz/piping.py:104, in Pipe.pipe(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#      55 def pipe(self,
#      56          format: typing.Optional[str] = None,
#      57          renderer: typing.Optional[str] = None,
#    (...)
#      61          engine: typing.Optional[str] = None,
#      62          encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
#      63     """Return the source piped through the Graphviz layout command.
#      64
#      65     Args:
#    (...)
#     102         '<?xml version='
#     103     """
# --> 104     return self._pipe_legacy(format,
#     105                              renderer=renderer,
#     106                              formatter=formatter,
#     107                              neato_no_op=neato_no_op,
#     108                              quiet=quiet,
#     109                              engine=engine,
#     110                              encoding=encoding)
#
# File /opt/homebrew/lib/python3.11/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/graphviz/piping.py:121, in Pipe._pipe_legacy(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     112 @_tools.deprecate_positional_args(supported_number=2)
#     113 def _pipe_legacy(self,
#     114                  format: typing.Optional[str] = None,
#    (...)
#     119                  engine: typing.Optional[str] = None,
#     120                  encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
# --> 121     return self._pipe_future(format,
#     122                              renderer=renderer,
#     123                              formatter=formatter,
#     124                              neato_no_op=neato_no_op,
#     125                              quiet=quiet,
#     126                              engine=engine,
#     127                              encoding=encoding)
#
# File /opt/homebrew/lib/python3.11/site-packages/graphviz/piping.py:161, in Pipe._pipe_future(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     159     else:
#     160         return raw.decode(encoding)
# --> 161 return self._pipe_lines(*args, input_encoding=self.encoding, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/graphviz/backend/piping.py:161, in pipe_lines(engine, format, input_lines, input_encoding, renderer, formatter, neato_no_op, quiet)
#     155 cmd = dot_command.command(engine, format,
#     156                           renderer=renderer,
#     157                           formatter=formatter,
#     158                           neato_no_op=neato_no_op)
#     159 kwargs = {'input_lines': (line.encode(input_encoding) for line in input_lines)}
# --> 161 proc = execute.run_check(cmd, capture_output=True, quiet=quiet, **kwargs)
#     162 return proc.stdout
#
# File /opt/homebrew/lib/python3.11/site-packages/graphviz/backend/execute.py:84, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      82 except OSError as e:
#      83     if e.errno == errno.ENOENT:
# ---> 84         raise ExecutableNotFound(cmd) from e
#      85     raise
#      87 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute PosixPath('dot'), make sure the Graphviz executables are on your systems' PATH

# %%
# np.array(x_test)
# x_test[0]
# 61	False	True	1	1	1	2	2	1	2	2	2	1	2	2
test = [61, False, True, 1, 1, 1, 2, 1, 1, 2, 2, 2, 1, 2, 2]
xgb_pred = xgb.predict_proba([test])
print(xgb_pred)
# Out:
# [[0.07536274 0.92463726]]

# %%
import pickle

# Save model to file
with open("xgb_model.pkl", "wb") as file:
    pickle.dump(xgb, file)

# %%
with open("xgb_model.pkl", "rb") as file:
    loaded_xgb = pickle.load(file)

# %%
test = [61, False, True, 1, 1, 1, 2, 1, 1, 2, 2, 2, 1, 2, 2]
xgb_pred = loaded_xgb.predict_proba([test])
print(xgb_pred)
# Out:
# [[0.07536274 0.92463726]]

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

regularization_parameter = 0.003

neural_model = Sequential([tf.keras.layers.Dense(units=32, input_dim=(x_train.shape[-1]), activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=64, activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=128, activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dropout(0.3),
                    tf.keras.layers.Dense(units=16,activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=1, activation="sigmoid")
                    ])

print(neural_model.summary())

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get("accuracy") == 1.0):
            print("\nAccuracy is 100% so canceling training!")
            self.model.stop_training = True

callbacks = myCallback()


neural_model.compile(optimizer = Adam(learning_rate = 0.001), 
                     loss = "binary_crossentropy", 
                     metrics = ["accuracy"])

history = neural_model.fit(x_train, y_train,
                           epochs = 150,
                           verbose = 1,
                           batch_size = 64,
                           validation_data = (x_test, y_test),
                           callbacks = [callbacks])
# Out:
# Epoch 1/150
# 4/4 [==============================] - 1s 92ms/step - loss: 4.4587 - accuracy: 0.5727 - val_loss: 4.3342 - val_accuracy: 0.7857
# Epoch 2/150
# 4/4 [==============================] - 0s 18ms/step - loss: 4.2574 - accuracy: 0.8636 - val_loss: 4.1814 - val_accuracy: 0.7857
# Epoch 3/150
# 4/4 [==============================] - 0s 18ms/step - loss: 4.0778 - accuracy: 0.8818 - val_loss: 4.0458 - val_accuracy: 0.7857
# Epoch 4/150
# 4/4 [==============================] - 0s 16ms/step - loss: 3.9063 - accuracy: 0.8818 - val_loss: 3.9211 - val_accuracy: 0.7857
# Epoch 5/150
# 4/4 [==============================] - 0s 16ms/step - loss: 3.7662 - accuracy: 0.8818 - val_loss: 3.8074 - val_accuracy: 0.7857
# Epoch 6/150
# 4/4 [==============================] - 0s 16ms/step - loss: 3.6402 - accuracy: 0.8818 - val_loss: 3.7000 - val_accuracy: 0.7857
# Epoch 7/150
# 4/4 [==============================] - 0s 17ms/step - loss: 3.5040 - accuracy: 0.8818 - val_loss: 3.5934 - val_accuracy: 0.7857
# Epoch 8/150
# 4/4 [==============================] - 0s 17ms/step - loss: 3.3851 - accuracy: 0.8818 - val_loss: 3.4847 - val_accuracy: 0.7857
# Epoch 9/150
# 4/4 [==============================] - 0s 17ms/step - loss: 3.2713 - accuracy: 0.8818 - val_loss: 3.3720 - val_accuracy: 0.7857
# Epoch 10/150
# 4/4 [==============================] - 0s 17ms/step - loss: 3.1570 - accuracy: 0.8818 - val_loss: 3.2551 - val_accuracy: 0.7857
# Epoch 11/150
# 4/4 [==============================] - 0s 20ms/step - loss: 3.0366 - accuracy: 0.8818 - val_loss: 3.1397 - val_accuracy: 0.7857
# Epoch 12/150
# 4/4 [==============================] - 0s 17ms/step - loss: 2.9307 - accuracy: 0.8818 - val_loss: 3.0260 - val_accuracy: 0.7857
# Epoch 13/150
# 4/4 [==============================] - 0s 17ms/step - loss: 2.8269 - accuracy: 0.8818 - val_loss: 2.9115 - val_accuracy: 0.7857
# Epoch 14/150
# 4/4 [==============================] - 0s 16ms/step - loss: 2.7253 - accuracy: 0.8818 - val_loss: 2.8009 - val_accuracy: 0.7857
# Epoch 15/150
# 4/4 [==============================] - 0s 16ms/step - loss: 2.6196 - accuracy: 0.8818 - val_loss: 2.6957 - val_accuracy: 0.7857
# Epoch 16/150
# 4/4 [==============================] - 0s 18ms/step - loss: 2.5219 - accuracy: 0.8818 - val_loss: 2.5931 - val_accuracy: 0.7857
# Epoch 17/150
# 4/4 [==============================] - 0s 16ms/step - loss: 2.4207 - accuracy: 0.8818 - val_loss: 2.4942 - val_accuracy: 0.7857
# Epoch 18/150
# 4/4 [==============================] - 0s 17ms/step - loss: 2.3264 - accuracy: 0.8818 - val_loss: 2.3985 - val_accuracy: 0.7857
# Epoch 19/150
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2350 - accuracy: 0.8818 - val_loss: 2.3037 - val_accuracy: 0.7857
# Epoch 20/150
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1427 - accuracy: 0.8818 - val_loss: 2.2149 - val_accuracy: 0.7857
# Epoch 21/150
# 4/4 [==============================] - 0s 18ms/step - loss: 2.0577 - accuracy: 0.8818 - val_loss: 2.1300 - val_accuracy: 0.7857
# Epoch 22/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.9678 - accuracy: 0.8818 - val_loss: 2.0460 - val_accuracy: 0.7857
# Epoch 23/150
# 4/4 [==============================] - 0s 17ms/step - loss: 1.8890 - accuracy: 0.8818 - val_loss: 1.9599 - val_accuracy: 0.7857
# Epoch 24/150
# 4/4 [==============================] - 0s 17ms/step - loss: 1.8127 - accuracy: 0.8818 - val_loss: 1.8786 - val_accuracy: 0.7857
# Epoch 25/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.7291 - accuracy: 0.8818 - val_loss: 1.7998 - val_accuracy: 0.7857
# Epoch 26/150
# 4/4 [==============================] - 0s 17ms/step - loss: 1.6532 - accuracy: 0.8818 - val_loss: 1.7263 - val_accuracy: 0.7857
# Epoch 27/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.5853 - accuracy: 0.8818 - val_loss: 1.6543 - val_accuracy: 0.7857
# Epoch 28/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.5145 - accuracy: 0.8818 - val_loss: 1.5878 - val_accuracy: 0.7857
# Epoch 29/150
# 4/4 [==============================] - 0s 17ms/step - loss: 1.4489 - accuracy: 0.8818 - val_loss: 1.5212 - val_accuracy: 0.7857
# Epoch 30/150
# 4/4 [==============================] - 0s 17ms/step - loss: 1.3827 - accuracy: 0.8818 - val_loss: 1.4572 - val_accuracy: 0.7857
# Epoch 31/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.3256 - accuracy: 0.8818 - val_loss: 1.3953 - val_accuracy: 0.7857
# Epoch 32/150
# 4/4 [==============================] - 0s 17ms/step - loss: 1.2693 - accuracy: 0.8818 - val_loss: 1.3345 - val_accuracy: 0.7857
# Epoch 33/150
# 4/4 [==============================] - 0s 17ms/step - loss: 1.2069 - accuracy: 0.8818 - val_loss: 1.2781 - val_accuracy: 0.7857
# Epoch 34/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1544 - accuracy: 0.8818 - val_loss: 1.2256 - val_accuracy: 0.7857
# Epoch 35/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.1063 - accuracy: 0.8818 - val_loss: 1.1739 - val_accuracy: 0.7857
# Epoch 36/150
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0582 - accuracy: 0.8818 - val_loss: 1.1266 - val_accuracy: 0.7857
# Epoch 37/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0102 - accuracy: 0.8818 - val_loss: 1.0818 - val_accuracy: 0.7857
# Epoch 38/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.9691 - accuracy: 0.8818 - val_loss: 1.0378 - val_accuracy: 0.7857
# Epoch 39/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.9249 - accuracy: 0.8818 - val_loss: 0.9972 - val_accuracy: 0.7857
# Epoch 40/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8894 - accuracy: 0.8818 - val_loss: 0.9591 - val_accuracy: 0.7857
# Epoch 41/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8546 - accuracy: 0.8818 - val_loss: 0.9250 - val_accuracy: 0.7857
# Epoch 42/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8192 - accuracy: 0.8818 - val_loss: 0.8942 - val_accuracy: 0.7857
# Epoch 43/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7896 - accuracy: 0.8818 - val_loss: 0.8637 - val_accuracy: 0.7857
# Epoch 44/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7643 - accuracy: 0.8909 - val_loss: 0.8349 - val_accuracy: 0.7857
# Epoch 45/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7367 - accuracy: 0.8909 - val_loss: 0.8085 - val_accuracy: 0.7857
# Epoch 46/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7103 - accuracy: 0.9091 - val_loss: 0.7844 - val_accuracy: 0.7857
# Epoch 47/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6922 - accuracy: 0.9091 - val_loss: 0.7628 - val_accuracy: 0.8036
# Epoch 48/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6667 - accuracy: 0.9182 - val_loss: 0.7433 - val_accuracy: 0.8036
# Epoch 49/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6432 - accuracy: 0.9136 - val_loss: 0.7242 - val_accuracy: 0.8036
# Epoch 50/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6299 - accuracy: 0.9136 - val_loss: 0.7061 - val_accuracy: 0.8036
# Epoch 51/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6150 - accuracy: 0.9227 - val_loss: 0.6898 - val_accuracy: 0.8036
# Epoch 52/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5993 - accuracy: 0.9318 - val_loss: 0.6747 - val_accuracy: 0.8036
# Epoch 53/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5887 - accuracy: 0.9273 - val_loss: 0.6599 - val_accuracy: 0.8036
# Epoch 54/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5690 - accuracy: 0.9318 - val_loss: 0.6468 - val_accuracy: 0.8036
# Epoch 55/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5568 - accuracy: 0.9273 - val_loss: 0.6334 - val_accuracy: 0.8036
# Epoch 56/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5435 - accuracy: 0.9273 - val_loss: 0.6205 - val_accuracy: 0.8214
# Epoch 57/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5330 - accuracy: 0.9318 - val_loss: 0.6074 - val_accuracy: 0.8214
# Epoch 58/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5207 - accuracy: 0.9182 - val_loss: 0.5958 - val_accuracy: 0.8929
# Epoch 59/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5086 - accuracy: 0.9227 - val_loss: 0.5834 - val_accuracy: 0.8929
# Epoch 60/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5042 - accuracy: 0.9273 - val_loss: 0.5742 - val_accuracy: 0.8929
# Epoch 61/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4903 - accuracy: 0.9273 - val_loss: 0.5657 - val_accuracy: 0.8929
# Epoch 62/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4830 - accuracy: 0.9318 - val_loss: 0.5587 - val_accuracy: 0.8929
# Epoch 63/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4750 - accuracy: 0.9227 - val_loss: 0.5524 - val_accuracy: 0.8929
# Epoch 64/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4674 - accuracy: 0.9227 - val_loss: 0.5445 - val_accuracy: 0.9107
# Epoch 65/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4622 - accuracy: 0.9318 - val_loss: 0.5370 - val_accuracy: 0.9107
# Epoch 66/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4557 - accuracy: 0.9273 - val_loss: 0.5305 - val_accuracy: 0.9107
# Epoch 67/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4493 - accuracy: 0.9318 - val_loss: 0.5240 - val_accuracy: 0.9107
# Epoch 68/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4432 - accuracy: 0.9318 - val_loss: 0.5182 - val_accuracy: 0.9107
# Epoch 69/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4353 - accuracy: 0.9318 - val_loss: 0.5131 - val_accuracy: 0.9107
# Epoch 70/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4375 - accuracy: 0.9273 - val_loss: 0.5076 - val_accuracy: 0.9107
# Epoch 71/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4257 - accuracy: 0.9364 - val_loss: 0.5033 - val_accuracy: 0.9107
# Epoch 72/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4235 - accuracy: 0.9364 - val_loss: 0.4978 - val_accuracy: 0.9107
# Epoch 73/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4192 - accuracy: 0.9318 - val_loss: 0.4920 - val_accuracy: 0.9107
# Epoch 74/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4106 - accuracy: 0.9364 - val_loss: 0.4877 - val_accuracy: 0.9107
# Epoch 75/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4052 - accuracy: 0.9455 - val_loss: 0.4832 - val_accuracy: 0.9107
# Epoch 76/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4051 - accuracy: 0.9455 - val_loss: 0.4789 - val_accuracy: 0.9107
# Epoch 77/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3988 - accuracy: 0.9409 - val_loss: 0.4745 - val_accuracy: 0.9107
# Epoch 78/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3957 - accuracy: 0.9455 - val_loss: 0.4698 - val_accuracy: 0.9107
# Epoch 79/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3929 - accuracy: 0.9409 - val_loss: 0.4654 - val_accuracy: 0.9107
# Epoch 80/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3910 - accuracy: 0.9455 - val_loss: 0.4608 - val_accuracy: 0.9107
# Epoch 81/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3815 - accuracy: 0.9455 - val_loss: 0.4569 - val_accuracy: 0.9107
# Epoch 82/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3814 - accuracy: 0.9500 - val_loss: 0.4533 - val_accuracy: 0.9107
# Epoch 83/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3776 - accuracy: 0.9409 - val_loss: 0.4492 - val_accuracy: 0.9107
# Epoch 84/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3713 - accuracy: 0.9455 - val_loss: 0.4466 - val_accuracy: 0.9107
# Epoch 85/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3695 - accuracy: 0.9500 - val_loss: 0.4439 - val_accuracy: 0.9107
# Epoch 86/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3681 - accuracy: 0.9455 - val_loss: 0.4405 - val_accuracy: 0.9107
# Epoch 87/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3633 - accuracy: 0.9455 - val_loss: 0.4358 - val_accuracy: 0.9107
# Epoch 88/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3613 - accuracy: 0.9500 - val_loss: 0.4323 - val_accuracy: 0.9107
# Epoch 89/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3609 - accuracy: 0.9455 - val_loss: 0.4295 - val_accuracy: 0.9107
# Epoch 90/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3532 - accuracy: 0.9500 - val_loss: 0.4275 - val_accuracy: 0.9107
# Epoch 91/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3548 - accuracy: 0.9455 - val_loss: 0.4248 - val_accuracy: 0.9107
# Epoch 92/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3517 - accuracy: 0.9545 - val_loss: 0.4213 - val_accuracy: 0.9107
# Epoch 93/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3485 - accuracy: 0.9455 - val_loss: 0.4176 - val_accuracy: 0.9107
# Epoch 94/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3422 - accuracy: 0.9591 - val_loss: 0.4154 - val_accuracy: 0.9107
# Epoch 95/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3438 - accuracy: 0.9500 - val_loss: 0.4127 - val_accuracy: 0.9107
# Epoch 96/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3385 - accuracy: 0.9409 - val_loss: 0.4096 - val_accuracy: 0.9107
# Epoch 97/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3391 - accuracy: 0.9500 - val_loss: 0.4075 - val_accuracy: 0.9107
# Epoch 98/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3372 - accuracy: 0.9500 - val_loss: 0.4052 - val_accuracy: 0.9107
# Epoch 99/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3293 - accuracy: 0.9500 - val_loss: 0.4031 - val_accuracy: 0.9107
# Epoch 100/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3306 - accuracy: 0.9500 - val_loss: 0.4011 - val_accuracy: 0.9107
# Epoch 101/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3296 - accuracy: 0.9591 - val_loss: 0.3981 - val_accuracy: 0.9107
# Epoch 102/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3252 - accuracy: 0.9545 - val_loss: 0.3957 - val_accuracy: 0.9107
# Epoch 103/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3228 - accuracy: 0.9545 - val_loss: 0.3932 - val_accuracy: 0.9107
# Epoch 104/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3228 - accuracy: 0.9500 - val_loss: 0.3911 - val_accuracy: 0.9107
# Epoch 105/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3226 - accuracy: 0.9500 - val_loss: 0.3901 - val_accuracy: 0.9107
# Epoch 106/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3202 - accuracy: 0.9500 - val_loss: 0.3883 - val_accuracy: 0.9107
# Epoch 107/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3181 - accuracy: 0.9545 - val_loss: 0.3859 - val_accuracy: 0.9107
# Epoch 108/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3197 - accuracy: 0.9500 - val_loss: 0.3828 - val_accuracy: 0.9107
# Epoch 109/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3099 - accuracy: 0.9545 - val_loss: 0.3806 - val_accuracy: 0.9107
# Epoch 110/150
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3092 - accuracy: 0.9455 - val_loss: 0.3786 - val_accuracy: 0.9107
# Epoch 111/150
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3071 - accuracy: 0.9636 - val_loss: 0.3764 - val_accuracy: 0.9286
# Epoch 112/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3093 - accuracy: 0.9500 - val_loss: 0.3745 - val_accuracy: 0.9286
# Epoch 113/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3047 - accuracy: 0.9455 - val_loss: 0.3708 - val_accuracy: 0.9464
# Epoch 114/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3051 - accuracy: 0.9500 - val_loss: 0.3680 - val_accuracy: 0.9464
# Epoch 115/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3041 - accuracy: 0.9500 - val_loss: 0.3668 - val_accuracy: 0.9464
# Epoch 116/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3045 - accuracy: 0.9500 - val_loss: 0.3647 - val_accuracy: 0.9464
# Epoch 117/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3000 - accuracy: 0.9409 - val_loss: 0.3621 - val_accuracy: 0.9464
# Epoch 118/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2954 - accuracy: 0.9455 - val_loss: 0.3596 - val_accuracy: 0.9464
# Epoch 119/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2969 - accuracy: 0.9591 - val_loss: 0.3578 - val_accuracy: 0.9464
# Epoch 120/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2916 - accuracy: 0.9455 - val_loss: 0.3568 - val_accuracy: 0.9464
# Epoch 121/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2908 - accuracy: 0.9500 - val_loss: 0.3559 - val_accuracy: 0.9464
# Epoch 122/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2880 - accuracy: 0.9500 - val_loss: 0.3538 - val_accuracy: 0.9464
# Epoch 123/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2944 - accuracy: 0.9500 - val_loss: 0.3523 - val_accuracy: 0.9464
# Epoch 124/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2875 - accuracy: 0.9500 - val_loss: 0.3507 - val_accuracy: 0.9464
# Epoch 125/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2869 - accuracy: 0.9500 - val_loss: 0.3501 - val_accuracy: 0.9464
# Epoch 126/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2872 - accuracy: 0.9545 - val_loss: 0.3500 - val_accuracy: 0.9464
# Epoch 127/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2827 - accuracy: 0.9500 - val_loss: 0.3497 - val_accuracy: 0.9464
# Epoch 128/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2844 - accuracy: 0.9545 - val_loss: 0.3481 - val_accuracy: 0.9464
# Epoch 129/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2788 - accuracy: 0.9500 - val_loss: 0.3455 - val_accuracy: 0.9464
# Epoch 130/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2787 - accuracy: 0.9455 - val_loss: 0.3440 - val_accuracy: 0.9464
# Epoch 131/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2811 - accuracy: 0.9500 - val_loss: 0.3433 - val_accuracy: 0.9464
# Epoch 132/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2783 - accuracy: 0.9500 - val_loss: 0.3422 - val_accuracy: 0.9464
# Epoch 133/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2752 - accuracy: 0.9545 - val_loss: 0.3403 - val_accuracy: 0.9464
# Epoch 134/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2751 - accuracy: 0.9500 - val_loss: 0.3383 - val_accuracy: 0.9464
# Epoch 135/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2735 - accuracy: 0.9545 - val_loss: 0.3365 - val_accuracy: 0.9464
# Epoch 136/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2737 - accuracy: 0.9545 - val_loss: 0.3354 - val_accuracy: 0.9464
# Epoch 137/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2699 - accuracy: 0.9591 - val_loss: 0.3349 - val_accuracy: 0.9464
# Epoch 138/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2724 - accuracy: 0.9500 - val_loss: 0.3345 - val_accuracy: 0.9464
# Epoch 139/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2692 - accuracy: 0.9500 - val_loss: 0.3324 - val_accuracy: 0.9464
# Epoch 140/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2718 - accuracy: 0.9500 - val_loss: 0.3312 - val_accuracy: 0.9464
# Epoch 141/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2700 - accuracy: 0.9500 - val_loss: 0.3308 - val_accuracy: 0.9464
# Epoch 142/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2653 - accuracy: 0.9455 - val_loss: 0.3295 - val_accuracy: 0.9464
# Epoch 143/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2662 - accuracy: 0.9545 - val_loss: 0.3280 - val_accuracy: 0.9464
# Epoch 144/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2710 - accuracy: 0.9500 - val_loss: 0.3263 - val_accuracy: 0.9464
# Epoch 145/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2661 - accuracy: 0.9455 - val_loss: 0.3235 - val_accuracy: 0.9464
# Epoch 146/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2683 - accuracy: 0.9455 - val_loss: 0.3228 - val_accuracy: 0.9464
# Epoch 147/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2655 - accuracy: 0.9591 - val_loss: 0.3213 - val_accuracy: 0.9464
# Epoch 148/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2606 - accuracy: 0.9455 - val_loss: 0.3207 - val_accuracy: 0.9464
# Epoch 149/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2611 - accuracy: 0.9545 - val_loss: 0.3195 - val_accuracy: 0.9464
# Epoch 150/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2587 - accuracy: 0.9500 - val_loss: 0.3184 - val_accuracy: 0.9464

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs = range(len(acc)) # number of epochs

plt.figure(figsize=(20, 12))
plt.subplot(2,1,1)
plt.plot(epochs, acc, "yellow", label= "Training Accuracy")
plt.plot(epochs, val_acc, "black", label= "Validation Accuracy")
plt.title("Training and validation accuracy")
plt.legend()

plt.subplot(2,1,2)
plt.plot(epochs, loss, "yellow", label= "Training Loss")
plt.plot(epochs, val_loss, "black", label= "Validation Loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()
