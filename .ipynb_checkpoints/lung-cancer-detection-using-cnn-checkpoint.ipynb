# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the "../input/" directory.
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # Any results you write to the current directory are saved as output.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.callbacks import ReduceLROnPlateau
import cv2
import os
from PIL import Image
import numpy as np

def get_training_data(image_path):
    """Loads an image from the given path into a numpy array."""
    with Image.open(image_path) as img:
        return np.array(img)

# %%
bad_dir = './Datasets/Lung_images/malignant'
good_dir = './Datasets/Lung_images/benign'

# %%
x, y = [], []

for i in os.listdir(bad_dir + '/'):
    img = plt.imread(bad_dir + '/' + i)
    img = np.array(img)
    
    if img.shape[0] == 512 and img.shape[1] == 512 and img.shape[2] == 3:
        x.append(img)
        y.append(1)

for i in os.listdir(good_dir + '/'):
    img = plt.imread(good_dir + '/' + i)
    img = np.array(img)
    if img.shape[0] == 512 and img.shape[1] == 512 and img.shape[2] == 3:
        x.append(img)
        y.append(0)

x = np.asarray(x)
y = np.asarray(y)
x = x / 255.0

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
print(x_val.shape, y_val.shape)
# Out:
# (372, 512, 512, 3) (372,)
# (124, 512, 512, 3) (124,)
# (125, 512, 512, 3) (125,)

# %%
plt.figure(figsize = (5,5))
plt.imshow(x_train[2], cmap='gray')

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,
        samplewise_center=False,
        featurewise_std_normalization=False,
        samplewise_std_normalization=False,
        zca_whitening=False,
        rotation_range = 30,
        zoom_range = 0.2,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        vertical_flip=False)


datagen.fit(x_train)

# %% [markdown]
# For the data augmentation, i choosed to :
# 1. Randomly rotate some training images by 30 degrees
# 2. Randomly Zoom by 20% some training images
# 3. Randomly shift images horizontally by 10% of the width
# 4. Randomly shift images vertically by 10% of the height
# 5. Randomly flip images horizontally.
# Once our model is ready, we fit the training dataset.

# %%
model = Sequential()
model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (512,512,3)))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "rmsprop" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 512, 512, 32)      896
#
#  batch_normalization_10 (Ba  (None, 512, 512, 32)      128
#  tchNormalization)
#
#  max_pooling2d_10 (MaxPooli  (None, 256, 256, 32)      0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 256, 256, 64)      18496
#
#  dropout_8 (Dropout)         (None, 256, 256, 64)      0
#
#  batch_normalization_11 (Ba  (None, 256, 256, 64)      256
#  tchNormalization)
#
#  max_pooling2d_11 (MaxPooli  (None, 128, 128, 64)      0
#  ng2D)
#
#  conv2d_12 (Conv2D)          (None, 128, 128, 64)      36928
#
#  batch_normalization_12 (Ba  (None, 128, 128, 64)      256
#  tchNormalization)
#
#  max_pooling2d_12 (MaxPooli  (None, 64, 64, 64)        0
#  ng2D)
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 128)       73856
#
#  dropout_9 (Dropout)         (None, 64, 64, 128)       0
#
#  batch_normalization_13 (Ba  (None, 64, 64, 128)       512
#  tchNormalization)
#
#  max_pooling2d_13 (MaxPooli  (None, 32, 32, 128)       0
#  ng2D)
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 256)       295168
#
#  dropout_10 (Dropout)        (None, 32, 32, 256)       0
#
#  batch_normalization_14 (Ba  (None, 32, 32, 256)       1024
#  tchNormalization)
#
#  max_pooling2d_14 (MaxPooli  (None, 16, 16, 256)       0
#  ng2D)
#
#  flatten_2 (Flatten)         (None, 65536)             0
#
#  dense_4 (Dense)             (None, 128)               8388736
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 8816385 (33.63 MB)
# Trainable params: 8815297 (33.63 MB)
# Non-trainable params: 1088 (4.25 KB)
# _________________________________________________________________

# %%
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

# %%
history = model.fit(datagen.flow(x_train,y_train, batch_size = 32) ,epochs = 12 , validation_data = datagen.flow(x_val, y_val) ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/12
# 12/12 [==============================] - 48s 4s/step - loss: 0.3873 - accuracy: 0.8522 - val_loss: 0.8596 - val_accuracy: 0.8080 - lr: 0.0010
# Epoch 2/12
# 12/12 [==============================] - 48s 4s/step - loss: 0.3638 - accuracy: 0.8575 - val_loss: 2.9812 - val_accuracy: 0.8080 - lr: 0.0010
# Epoch 3/12
# 12/12 [==============================] - ETA: 0s - loss: 0.3156 - accuracy: 0.8575
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 12/12 [==============================] - 46s 4s/step - loss: 0.3156 - accuracy: 0.8575 - val_loss: 6.1633 - val_accuracy: 0.8080 - lr: 0.0010
# Epoch 4/12
# 12/12 [==============================] - 46s 4s/step - loss: 0.2072 - accuracy: 0.9113 - val_loss: 3.5080 - val_accuracy: 0.8080 - lr: 3.0000e-04
# Epoch 5/12
# 12/12 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.8978
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 12/12 [==============================] - 51s 4s/step - loss: 0.2344 - accuracy: 0.8978 - val_loss: 2.7367 - val_accuracy: 0.8080 - lr: 3.0000e-04
# Epoch 6/12
# 12/12 [==============================] - 45s 4s/step - loss: 0.1781 - accuracy: 0.9194 - val_loss: 2.8233 - val_accuracy: 0.8080 - lr: 9.0000e-05
# Epoch 7/12
# 12/12 [==============================] - ETA: 0s - loss: 0.2010 - accuracy: 0.8898
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 12/12 [==============================] - 46s 4s/step - loss: 0.2010 - accuracy: 0.8898 - val_loss: 1.9851 - val_accuracy: 0.8080 - lr: 9.0000e-05
# Epoch 8/12
# 12/12 [==============================] - 47s 4s/step - loss: 0.1682 - accuracy: 0.9140 - val_loss: 1.7639 - val_accuracy: 0.8080 - lr: 2.7000e-05
# Epoch 9/12
# 12/12 [==============================] - ETA: 0s - loss: 0.1893 - accuracy: 0.9032
# Epoch 9: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 12/12 [==============================] - 46s 4s/step - loss: 0.1893 - accuracy: 0.9032 - val_loss: 1.4655 - val_accuracy: 0.8080 - lr: 2.7000e-05
# Epoch 10/12
# 12/12 [==============================] - 46s 4s/step - loss: 0.2622 - accuracy: 0.8952 - val_loss: 1.0056 - val_accuracy: 0.8080 - lr: 8.1000e-06
# Epoch 11/12
# 12/12 [==============================] - ETA: 0s - loss: 0.1995 - accuracy: 0.9086
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 12/12 [==============================] - 45s 4s/step - loss: 0.1995 - accuracy: 0.9086 - val_loss: 0.9888 - val_accuracy: 0.8080 - lr: 8.1000e-06
# Epoch 12/12
# 12/12 [==============================] - 50s 4s/step - loss: 0.2198 - accuracy: 0.9274 - val_loss: 0.8340 - val_accuracy: 0.8160 - lr: 2.4300e-06

# %%
print("Loss of the model is - " , model.evaluate(x_test,y_test)[0])
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
# Out:
# 624/624 [==============================] - 0s 476us/step
# Loss of the model is -  0.2780601046024225
# 624/624 [==============================] - 0s 462us/step
# Accuracy of the model is -  90.22436141967773 %

# %%
epochs = [i for i in range(12)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Validation Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Training & Validation Loss")
plt.show()

# %%
predictions = model.predict(x_test)
predictions = predictions.reshape(1,-1)[0]
predictions[:15]

for i in range(len(predictions)):
    predictions[i] = (predictions[i] >= 0.5)
# Out:
# 4/4 [==============================] - 4s 855ms/step

# %%
print(classification_report(y_test, predictions, target_names = ['Benign (Class 0)','Malignant (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
#    Benign (Class 0)       0.83      1.00      0.91        20
# Malignant (Class 1)       1.00      0.96      0.98       104
#
#            accuracy                           0.97       124
#           macro avg       0.92      0.98      0.94       124
#        weighted avg       0.97      0.97      0.97       124

# %%
cm = confusion_matrix(y_test,predictions)
cm
# Out:
# array([[ 20,   0],
#        [  4, 100]])

# %%
plt.imshow(x_test[0])

# %%
test_prediction = model.predict(np.array([x_test[1]]))
# Out:
# 1/1 [==============================] - 0s 40ms/step

# %%
test_prediction
# Out:
# array([[0.18135889]], dtype=float32)

# %%
model.save_weights('cnn_weights.h5')

# %%
def getModelArchitecture():
    model = Sequential()
    model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (512,512,3)))
    model.add(BatchNormalization())
    model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
    model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
    model.add(Dropout(0.1))
    model.add(BatchNormalization())
    model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
    model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
    model.add(BatchNormalization())
    model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
    model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
    model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
    model.add(Flatten())
    model.add(Dense(units = 128 , activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(units = 1 , activation = 'sigmoid'))
    model.compile(optimizer = "rmsprop" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
    model.summary()
    return model

test = getModelArchitecture()  # assuming you have a function to create your model architecture
test.load_weights('cnn_weights.h5')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 512, 512, 32)      896
#
#  batch_normalization_20 (Ba  (None, 512, 512, 32)      128
#  tchNormalization)
#
#  max_pooling2d_20 (MaxPooli  (None, 256, 256, 32)      0
#  ng2D)
#
#  conv2d_21 (Conv2D)          (None, 256, 256, 64)      18496
#
#  dropout_16 (Dropout)        (None, 256, 256, 64)      0
#
#  batch_normalization_21 (Ba  (None, 256, 256, 64)      256
#  tchNormalization)
#
#  max_pooling2d_21 (MaxPooli  (None, 128, 128, 64)      0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 128, 128, 64)      36928
#
#  batch_normalization_22 (Ba  (None, 128, 128, 64)      256
#  tchNormalization)
#
#  max_pooling2d_22 (MaxPooli  (None, 64, 64, 64)        0
#  ng2D)
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 128)       73856
#
#  dropout_17 (Dropout)        (None, 64, 64, 128)       0
#
#  batch_normalization_23 (Ba  (None, 64, 64, 128)       512
#  tchNormalization)
#
#  max_pooling2d_23 (MaxPooli  (None, 32, 32, 128)       0
#  ng2D)
#
#  conv2d_24 (Conv2D)          (None, 32, 32, 256)       295168
#
#  dropout_18 (Dropout)        (None, 32, 32, 256)       0
#
#  batch_normalization_24 (Ba  (None, 32, 32, 256)       1024
#  tchNormalization)
#
#  max_pooling2d_24 (MaxPooli  (None, 16, 16, 256)       0
#  ng2D)
#
#  flatten_4 (Flatten)         (None, 65536)             0
#
#  dense_8 (Dense)             (None, 128)               8388736
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_9 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 8816385 (33.63 MB)
# Trainable params: 8815297 (33.63 MB)
# Non-trainable params: 1088 (4.25 KB)
# _________________________________________________________________

# %%
test_prediction = test.predict(np.array([x_test[1]]))
# Out:
# 1/1 [==============================] - 0s 82ms/step

# %%
test_prediction
# Out:
# array([[0.18135889]], dtype=float32)
